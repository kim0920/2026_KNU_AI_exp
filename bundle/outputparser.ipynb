# %%
# %pip install -Uq langchain-core langchain langchain-groq dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

llama_llm_model = ChatGroq(
    model = "llama-3.1-8b-instant"
)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_messages(
    [
        ("human","제천에 대해 100글자로 설명해줘")
    ]
)

parser = StrOutputParser()

msg = prompt.invoke({})

result = llama_llm_model.invoke(msg)

r = parser.invoke(result)

print(r)
# Out:
# 제천시는 대한민국의 충청북도에 위치한 시입니다. 시명은 '제물과 천안을 잇는 곳'을 의미하며, 충청북도 북부에 위치해 있습니다. 충북의 대표적인 관광지 중 하나로 유명한 제천한옥마을, 제천 세계한의학축제가 있습다.
